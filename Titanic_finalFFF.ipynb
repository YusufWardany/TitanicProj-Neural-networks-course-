# %% [markdown]
# # Project phasese:

# %% [markdown]
# <a id="Explanition of dataset"></a> <br>
# # **1. Explanition of dataset:**
# <h3> The data have 891 entries on train dataset and 418 on test dataset</h3>
# - 10 columns in train_csv and 9 columns in train_test

# %% [markdown]
# <h2>Competition Description: </h2>
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this challenge, we ask you to complete the analysis of what sorts of people were likely to survive. In particular, we ask you to apply the tools of machine learning to predict which passengers survived the tragedy.

# %% [markdown]
# <h3>Data Dictionary</h3><br>
# Variable	Definition	Key<br>
# <b>survival</b>	Survival	0 = No, 1 = Yes<br>
# <b>pclass</b>	Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd<br>
# <b>sex</b>	Sex	<br>
# <b>Age</b>	Age in years	<br>
# <b>sibsp</b>	# of siblings / spouses aboard the Titanic	<br>
# <b>parch</b>	# of parents / children aboard the Titanic	<br>
# <b>ticket</b>	Ticket number	<br>
# <b>fare</b>	Passenger fare	<br>
# <b>cabin</b>	Cabin number	<br>
# <b>embarked	</b>Port of Embarkation	C = Cherbourg, Q = Queenstown, S = Southampton<br>
# <h3>Variable Notes</h3><br>
# <b>pclass: </b>A proxy for socio-economic status (SES)<br>
# 1st = Upper<br>
# 2nd = Middle<br>
# 3rd = Lower<br>
# <b>age: </b>Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5<br>
# <b>sibsp:</b> The dataset defines family relations in this way...<br>
# - <b>Sibling </b>= brother, sister, stepbrother, stepsister<br>
# - <b>Spouse </b>= husband, wife (mistresses and fiancés were ignored)<br>
#
# <b>parch: </b>The dataset defines family relations in this way...<br>
# - <b>Parent</b> = mother, father<br>
# - <b>Child </b>= daughter, son, stepdaughter, stepson<br>
#
# Some children travelled only with a nanny, therefore parch=0 for them.<br>

# %% [markdown]
# I am using the beapproachs as possible but if you think I can do anything another best way, please, let me know.

# %% [markdown]
# <a id="Librarys"></a> <br>
# # **2. Librarys:**

# %%
#This librarys is to work with matrices
import pandas as pd
# This librarys is to work with vectors
import numpy as np
# This library is to create some graphics algorithmn
import seaborn as sns
# to render the graphs
import matplotlib.pyplot as plt
# import module to set some ploting parameters
from matplotlib import rcParams
# Library to work with Regular Expressions
import re

# This function makes the plot directly on browser
# %matplotlib inline

# Seting a universal figure size
rcParams['figure.figsize'] = 10,8

# %%
#!pip install seaborn

# %%
# Importing train dataset
df_train = pd.read_csv("train.csv")

# Importing test dataset
df_test = pd.read_csv("test.csv")

# %% [markdown]
# <a id="Known"></a> <br>
# # **3. First look at the data:**

# %% [markdown]
# I will start looking the type and informations of the datasets

# %%
#Looking data format and types
print(df_train.info())

# printing test info()
print(df_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB
# None

# %%
#Some Statistics
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Take a look at the data
(df_train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <a id="Known"></a> <br>
# # **4. Exploring the data:**

# %% [markdown]
# <h2>To try a new approach in the data, instend of removing name from attribute without using it we expract tittle of persons from it

# %%
#Looking how the data is and searching for a re patterns
df_train["Name"].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
#GettingLooking the prefix of all Passengers
df_train['Title'] = df_train.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))

#defining the figure size of our graphic
plt.figure(figsize=(12,5))

#Plotting the result
sns.countplot(x='Title', data=df_train, palette="hls")
plt.xlabel("Title", fontsize=16) #seting the xtitle and size
plt.ylabel("Count", fontsize=16) # Seting the ytitle and size
plt.title("Title Name Count", fontsize=20)
plt.xticks(rotation=45)
plt.show()

# %%
#Doing the same on df_test with regular expressions
df_test['Title'] = df_test.Name.apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))

# %% [markdown]
# ## Grouping some titles and ploting the results

# %%
# identify the social status of each title
Title_Dictionary = {
        "Capt":       "Officer",
        "Col":        "Officer",
        "Major":      "Officer",
        "Dr":         "Officer",
        "Rev":        "Officer",
        "Jonkheer":   "Royalty",
        "Don":        "Royalty",
        "Sir" :       "Royalty",
        "the Countess":"Royalty",
        "Dona":       "Royalty",
        "Lady" :      "Royalty",
        "Mme":        "Mrs",
        "Ms":         "Mrs",
        "Mrs" :       "Mrs",
        "Mlle":       "Miss",
        "Miss" :      "Miss",
        "Mr" :        "Mr",
        "Master" :    "Master"
                   }

# we map each title to correct category
df_train['Title'] = df_train.Title.map(Title_Dictionary)
df_test['Title'] = df_test.Title.map(Title_Dictionary)

# %% [markdown]
# ## Title grouped here we conclude that tittle affect Chances to survive
# ## as Master 0.575000
# ## as Miss   0.701087
# ## as Royalty 0.500000

# %%
#printing the chance to survive by each title
print("Chances to survive based on titles: ")
print(df_train.groupby("Title")["Survived"].mean())
# figure size
plt.figure(figsize=(12,5))

#Plotting the count of title by Survived or not category
sns.countplot(x='Title', data=df_train, palette="hls",
              hue="Survived")
plt.xlabel("Titles", fontsize=16)
plt.ylabel("Count", fontsize=16)
plt.title("Title Grouped Count", fontsize=20)
plt.xticks(rotation=45)
plt.show()
# Out:
# Chances to survive based on titles:
# Title
# Master     0.575000
# Miss       0.701087
# Mr         0.156673
# Mrs        0.795276
# Officer    0.277778
# Royalty    0.500000
# Name: Survived, dtype: float64

# %% [markdown]
# It's interesting... Children's and ladys first, huh?

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# <h1>  handle the Age variable that has a high number of NaN's, using some columns to correctly input he missing Age's

# %%
#First we look my distribuition without NaN's
#I will create a df to look distribuition
age_high_zero_died = df_train[(df_train["Age"] > 0) &
                              (df_train["Survived"] == 0)]
age_high_zero_surv = df_train[(df_train["Age"] > 0) &
                              (df_train["Survived"] == 1)]

#figure size
plt.figure(figsize=(10,5))
# Ploting the 2 variables that we create and compare the two
sns.distplot(age_high_zero_surv["Age"], bins=24, color='g')# green to which sur
sns.distplot(age_high_zero_died["Age"], bins=24, color='r')# red to which die
plt.title("Distribuition and density by Age",fontsize=20)
plt.xlabel("Age",fontsize=15)
plt.ylabel("Distribuition Died and Survived",fontsize=15)
plt.show()

# %%
#Let's group the median age by sex, pclass and title, to have any idea and see if there is relation
age_group = df_train.groupby(["Sex","Pclass","Title"])["Age"]

#printing the variabe that we created by median
print(age_group.median())
# Out:
# Sex     Pclass  Title
# female  1       Miss       30.0
#                 Mrs        40.0
#                 Officer    49.0
#                 Royalty    48.0
#         2       Miss       24.0
#                 Mrs        31.5
#         3       Miss       18.0
#                 Mrs        31.0
# male    1       Master      4.0
#                 Mr         40.0
#                 Officer    51.0
#                 Royalty    40.0
#         2       Master      1.0
#                 Mr         31.0
#                 Officer    46.5
#         3       Master      4.0
#                 Mr         26.0
# Name: Age, dtype: float64

# %% [markdown]
# <b> example: </b> an male in 2 class that is a Officer the median Age is 42. <br>
# And we will use that to complete the missing data

# %%
#inputing the values on Age Na's
# using the groupby to transform this variables
df_train.loc[df_train.Age.isnull(), 'Age'] = df_train.groupby(['Sex','Pclass','Title']).Age.transform('median')

# printing the total of nulls in Age Feature
print(df_train["Age"].isnull().sum())
# Out:
# 0

# %% [markdown]
# # result after adding missing values of age

# %%
#Let's see the result of the inputation
#seting the figure size
plt.figure(figsize=(12,5))

#ploting again the Age Distribuition after the transformation in our dataset
sns.distplot(df_train["Age"], bins=24)
plt.title("Distribuition and density by Age after filling missing values")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# Now let's categorize them

# %%
#separate by survivors or not

# figure size
plt.figure(figsize=(12,5))

# using facetgrid that is a great way to get information of our dataset
# Changed 'size' to 'height'
g = sns.FacetGrid(df_train, col='Survived', height=5)
g = g.map(sns.distplot, "Age")
plt.show()

# %%
#df_train.Age = df_train.Age.fillna(-0.5)

#creating the intervals that we need to cut each range of ages
interval = (0, 5, 12, 18, 25, 35, 60, 120)

#Seting the names that we want use to the categorys
cats = ['babies', 'Children', 'Teen', 'Student', 'Young', 'Adult', 'Senior']

# Applying the pd.cut and using the parameters that we created
df_train["Age_cat"] = pd.cut(df_train.Age, interval, labels=cats)

# Printing the new Category
df_train["Age_cat"].head()
# Out:
# 0    Student
# 1      Adult
# 2      Young
# 3      Young
# 4      Young
# Name: Age_cat, dtype: category
# Categories (7, object): ['babies' < 'Children' < 'Teen' < 'Student' < 'Young' < 'Adult' < 'Senior']

# %%
#Do the same to test dataset
interval = (0, 5, 12, 18, 25, 35, 60, 120)

#same as the other df train
cats = ['babies', 'Children', 'Teen', 'Student', 'Young', 'Adult', 'Senior']

# same that we used above in df train
df_test["Age_cat"] = pd.cut(df_test.Age, interval, labels=cats)

# %% [markdown]
# Now it look's better and clearly

# %%
#Describe of categorical Age

# Using pd.crosstab to understand the Survived rate by Age Category's
print(pd.crosstab(df_train.Age_cat, df_train.Survived))

#Seting the figure size
plt.figure(figsize=(12,10))

#Plotting the result
plt.subplot(2,1,1)
# The first positional argument should be 'x'
sns.countplot(x="Age_cat", data=df_train, hue="Survived", palette="hls")
plt.ylabel("Count", fontsize=18)
plt.xlabel("Age Categorys", fontsize=18)
plt.title("Age Distribution ", fontsize=20)

plt.subplot(2,1,2)
sns.swarmplot(x='Age_cat',y="Fare",data=df_train,
              hue="Survived", palette="hls", )
plt.ylabel("Fare Distribution", fontsize=18)
plt.xlabel("Age Categorys", fontsize=18)
plt.title("Fare Distribution by Age Categorys ", fontsize=20)

plt.subplots_adjust(hspace = 0.5, top = 0.9)

plt.show()
# Out:
# Survived    0   1
# Age_cat
# babies     15  33
# Children   16   9
# Teen       54  49
# Student   108  56
# Young     206  99
# Adult     133  91
# Senior     17   5

# %% [markdown]
# ## cross our Pclass with the Age_cat
# We will aggregate than to get the mean of Fare by each category pair

# %%
Age_fare = ['Pclass', 'Age_cat'] #seting the desired
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df_train[Age_fare[0]], df_train[Age_fare[1]],
            values=df_train['Fare'], aggfunc=['mean']).style.background_gradient(cmap = cm)
# Out:
# <style type="text/css">
# #T_8d3f9_row0_col0, #T_8d3f9_row0_col1, #T_8d3f9_row0_col2, #T_8d3f9_row0_col3, #T_8d3f9_row0_col4, #T_8d3f9_row0_col5, #T_8d3f9_row0_col6 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_8d3f9_row1_col0 {
#   background-color: #e1eee1;
#   color: #000000;
# }
# #T_8d3f9_row1_col1 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_8d3f9_row1_col2, #T_8d3f9_row1_col4 {
#   background-color: #deedde;
#   color: #000000;
# }
# #T_8d3f9_row1_col3 {
#   background-color: #c8e2c8;
#   color: #000000;
# }
# #T_8d3f9_row1_col5 {
#   background-color: #d2e7d2;
#   color: #000000;
# }
# #T_8d3f9_row1_col6 {
#   background-color: #dfeddf;
#   color: #000000;
# }
# #T_8d3f9_row2_col0, #T_8d3f9_row2_col1, #T_8d3f9_row2_col2, #T_8d3f9_row2_col3, #T_8d3f9_row2_col4, #T_8d3f9_row2_col5, #T_8d3f9_row2_col6 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_8d3f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d3f9_level0_col0" class="col_heading level0 col0" colspan="7">mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Age_cat</th>
#       <th id="T_8d3f9_level1_col0" class="col_heading level1 col0" >babies</th>
#       <th id="T_8d3f9_level1_col1" class="col_heading level1 col1" >Children</th>
#       <th id="T_8d3f9_level1_col2" class="col_heading level1 col2" >Teen</th>
#       <th id="T_8d3f9_level1_col3" class="col_heading level1 col3" >Student</th>
#       <th id="T_8d3f9_level1_col4" class="col_heading level1 col4" >Young</th>
#       <th id="T_8d3f9_level1_col5" class="col_heading level1 col5" >Adult</th>
#       <th id="T_8d3f9_level1_col6" class="col_heading level1 col6" >Senior</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d3f9_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_8d3f9_row0_col0" class="data row0 col0" >128.319433</td>
#       <td id="T_8d3f9_row0_col1" class="data row0 col1" >120.000000</td>
#       <td id="T_8d3f9_row0_col2" class="data row0 col2" >122.537500</td>
#       <td id="T_8d3f9_row0_col3" class="data row0 col3" >113.002081</td>
#       <td id="T_8d3f9_row0_col4" class="data row0 col4" >92.444107</td>
#       <td id="T_8d3f9_row0_col5" class="data row0 col5" >72.556092</td>
#       <td id="T_8d3f9_row0_col6" class="data row0 col6" >59.969050</td>
#     </tr>
#     <tr>
#       <th id="T_8d3f9_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_8d3f9_row1_col0" class="data row1 col0" >28.179492</td>
#       <td id="T_8d3f9_row1_col1" class="data row1 col1" >30.562500</td>
#       <td id="T_8d3f9_row1_col2" class="data row1 col2" >21.172567</td>
#       <td id="T_8d3f9_row1_col3" class="data row1 col3" >24.588050</td>
#       <td id="T_8d3f9_row1_col4" class="data row1 col4" >17.381964</td>
#       <td id="T_8d3f9_row1_col5" class="data row1 col5" >19.760638</td>
#       <td id="T_8d3f9_row1_col6" class="data row1 col6" >10.500000</td>
#     </tr>
#     <tr>
#       <th id="T_8d3f9_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_8d3f9_row2_col0" class="data row2 col0" >23.795309</td>
#       <td id="T_8d3f9_row2_col1" class="data row2 col1" >27.326250</td>
#       <td id="T_8d3f9_row2_col2" class="data row2 col2" >15.147158</td>
#       <td id="T_8d3f9_row2_col3" class="data row2 col3" >8.903373</td>
#       <td id="T_8d3f9_row2_col4" class="data row2 col4" >12.727280</td>
#       <td id="T_8d3f9_row2_col5" class="data row2 col5" >13.334195</td>
#       <td id="T_8d3f9_row2_col6" class="data row2 col6" >7.820000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Very interesting. We can see that babies has the highest mean value.

# %% [markdown]
# ### Looking the Fare distribuition to survivors and not survivors
# ### we conclude from that low fare have very high change of not Survived

# %%
# Seting the figure size
plt.figure(figsize=(12,5))

# Understanding the Fare Distribuition
sns.distplot(df_train[df_train.Survived == 0]["Fare"],
             bins=50, color='r')
sns.distplot(df_train[df_train.Survived == 1]["Fare"],
             bins=50, color='g')
plt.title("Fare Distribuition by Survived", fontsize=20)
plt.xlabel("Fare", fontsize=15)
plt.ylabel("Density",fontsize=15)
plt.show()

# %% [markdown]
# <br>
# Description of Fare variable<br>
# - Min: 0<br>
# - Median: 14.45<br>
# - Mean: 32.20<br>
# - Max: 512.32<br>
# - Std: 49.69<br>
#
# <h3> create a categorical variable to treat the Fare expend</h3><br>
# I will use the same technique used in Age but now I will use the quantiles to binning

# %%
#Filling the NA's with -0.5
df_train.Fare = df_train.Fare.fillna(-0.5)

#intervals to categorize
quant = (-1, 0, 8, 15, 31, 600)

#Labels without input values
label_quants = ['NoInf', 'quart_1', 'quart_2', 'quart_3', 'quart_4']

#doing the cut in fare and puting in a new column
df_train["Fare_cat"] = pd.cut(df_train.Fare, quant, labels=label_quants)

#Description of transformation
print(pd.crosstab(df_train.Fare_cat, df_train.Survived))

plt.figure(figsize=(12,5))

#Plotting the new feature
sns.countplot(x="Fare_cat", hue="Survived", data=df_train, palette="hls")
plt.title("Count of survived x Fare expending",fontsize=20)
plt.xlabel("Fare Cat",fontsize=15)
plt.ylabel("Count",fontsize=15)

plt.show()
# Out:
# Survived    0    1
# Fare_cat
# NoInf      14    1
# quart_1   175   51
# quart_2   155   62
# quart_3   112   99
# quart_4    93  129

# %%
# Replicate the same to df_test
df_test.Fare = df_test.Fare.fillna(-0.5)

quant = (-1, 0, 8, 15, 31, 1000)
label_quants = ['NoInf', 'quart_1', 'quart_2', 'quart_3', 'quart_4']

df_test["Fare_cat"] = pd.cut(df_test.Fare, quant, labels=label_quants)

# %% [markdown]
# <h2>To complete this part, I will now work on "Names"

# %%
#Now lets drop the variable Fare, Age and ticket that is irrelevant now
del df_train["Fare"]
del df_train["Ticket"]
del df_train["Age"]
del df_train["Cabin"]
del df_train["Name"]

#same in df_test
del df_test["Fare"]
del df_test["Ticket"]
del df_test["Age"]
del df_test["Cabin"]
del df_test["Name"]

# %%
#Looking the result of transformations
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  SibSp  Parch Embarked Title  \
# 0            1         0       3    male      1      0        S    Mr
# 1            2         1       1  female      1      0        C   Mrs
# 2            3         1       3  female      0      0        S  Miss
# 3            4         1       1  female      1      0        S   Mrs
# 4            5         0       3    male      0      0        S    Mr
#
#    Age_cat Fare_cat
# 0  Student  quart_1
# 1    Adult  quart_4
# 2    Young  quart_1
# 3    Young  quart_4
# 4    Young  quart_2

# %% [markdown]
# <h1> explore on dataset

# %% [markdown]
# Now, lets start explore the data

# %%
# Let see how many people die or survived
print("Total of Survived or not: ")
print(df_train.groupby("Survived")["PassengerId"].count())
plt.figure(figsize=(12,5))
sns.countplot(x="Survived", data=df_train,palette="hls")
plt.title('Total Distribuition by survived or not', fontsize=22)
plt.xlabel('Target Distribuition', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.show()
# Out:
# Total of Survived or not:
# Survived
# 0    549
# 1    342
# Name: PassengerId, dtype: int64

# %%
print(pd.crosstab(df_train.Survived, df_train.Sex))

plt.figure(figsize=(12,5))
sns.countplot(x="Sex", data=df_train, hue="Survived",palette="hls")
plt.title('Sex Distribuition by survived or not', fontsize=20)
plt.xlabel('Sex Distribuition',fontsize=17)
plt.ylabel('Count', fontsize=17)

plt.show()
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %% [markdown]
# <h2>We can look that % dies to mens are much higher than female

# %% [markdown]
# <h1>finding some relation between Pclass and Embarked to see if might have some information to build the model
# we notice that most frequent Embarked is S

# %%
# Distribuition by class
print(pd.crosstab(df_train.Pclass, df_train.Embarked))
plt.figure(figsize=(12,5))
sns.countplot(x="Embarked", data=df_train, hue="Pclass",palette="hls")
plt.title('Embarked x Pclass Count', fontsize=20)
plt.xlabel('Embarked with PClass',fontsize=17)
plt.ylabel('Count', fontsize=17)

plt.show()
# Out:
# Embarked   C   Q    S
# Pclass
# 1         85   2  127
# 2         17   3  164
# 3         66  72  353

# %%
#lets input the NA's with the highest frequency
df_train["Embarked"] = df_train["Embarked"].fillna('S')

# %%
# Exploring Survivors vs Embarked
print(pd.crosstab(df_train.Survived, df_train.Embarked))

plt.figure(figsize=(12,5))

sns.countplot(x="Embarked", data=df_train, hue="Survived",palette="hls")
plt.title('Class Distribuition by survived or not',fontsize=20)
plt.xlabel('Embarked',fontsize=17)
plt.ylabel('Count', fontsize=17)

plt.show()
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  219

# %%
# Exploring Survivors vs Pclass
print(pd.crosstab(df_train.Survived, df_train.Pclass))

plt.figure(figsize=(12,5))

sns.countplot(x="Pclass", data=df_train, hue="Survived",palette="hls")
plt.xlabel('PClass',fontsize=17)
plt.ylabel('Count', fontsize=17)
plt.title('Class Distribuition by Survived or not', fontsize=20)

plt.show()
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %% [markdown]
# <b>Looking the graphs, is clear that 3st class and Embarked at Southampton have a high probabilities to not survive</b>

# %% [markdown]
#  the Sibsp and prch variables

# %%
# Replace 'factorplot' with 'catplot'
g = sns.catplot(x="SibSp", y="Survived", data=df_train,
                kind="bar", height=5, aspect=1.6, palette="hls")
g.set_ylabels("Probability(Survive)", fontsize=15)
g.set_xlabels("SibSp Number", fontsize=15)

plt.show()

# %% [markdown]
#  With "1 or 2" siblings/spouses have more chance to survived we con that high prop to serived

# %% [markdown]
# We can see a high standard deviation in the survival with 3 parents/children person's <br>
# Also that small families (1~2) have more chance to survival than single or big families

# %% [markdown]
# So to Finish our exploration I will create a new column to with familiees size

# %%
# Explore Parch feature vs Survived
# Replace 'factorplot' with 'catplot'
g = sns.catplot(x="Parch", y="Survived", data=df_train, kind="bar", height=6, palette="hls")
g.set_ylabels("survival probability")
plt.show() # Add plt.show() to display the plot

# %%
#Create a new column and sum the Parch + SibSp + 1 that refers the people self
df_train["FSize"] = df_train["Parch"] + df_train["SibSp"] + 1
df_test["FSize"] = df_test["Parch"] + df_test["SibSp"] + 1

# %%
print(pd.crosstab(df_train.FSize, df_train.Survived))

# Replace 'factorplot' with 'catplot' and adjust parameters
sns.catplot(x="FSize", y="Survived", data=df_train, kind="bar", height=6, aspect=1.6, palette="hls")
plt.show() # Add plt.show() to display the plot
# Out:
# Survived    0    1
# FSize
# 1         374  163
# 2          72   89
# 3          43   59
# 4           8   21
# 5          12    3
# 6          19    3
# 7           8    4
# 8           6    0
# 11          7    0

# %%
del df_train["SibSp"]
del df_train["Parch"]

del df_test["SibSp"]
del df_test["Parch"]

# %% [markdown]
# OK, its might be enough to start with the preprocess and builting the model

# %% [markdown]
# <a id="Preprocess"></a> <br>
# # **5. Preprocessing :**

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex Embarked Title  Age_cat Fare_cat  \
# 0            1         0       3    male        S    Mr  Student  quart_1
# 1            2         1       1  female        C   Mrs    Adult  quart_4
# 2            3         1       3  female        S  Miss    Young  quart_1
# 3            4         1       1  female        S   Mrs    Young  quart_4
# 4            5         0       3    male        S    Mr    Young  quart_2
#
#    FSize
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1

# %% [markdown]
# Now we might have information enough to think about the model structure

# %%
df_train = pd.get_dummies(df_train, columns=["Sex","Embarked","Age_cat","Fare_cat","Title"],\
                          prefix=["Sex","Emb","Age","Fare","Prefix"], drop_first=True)

df_test = pd.get_dummies(df_test, columns=["Sex","Embarked","Age_cat","Fare_cat","Title"],\
                         prefix=["Sex","Emb","Age","Fare","Prefix"], drop_first=True)

# %%
#Finallt, lets look the correlation of df_train
plt.figure(figsize=(15,12))
plt.title('Correlation of Features for Train Set')
sns.heatmap(df_train.astype(float).corr(),vmax=1.0,  annot=True)
plt.show()

# %%
df_train.shape
# Out:
# (891, 22)

# %%
train = df_train.drop(["Survived","PassengerId"],axis=1)
train_ = df_train["Survived"]

test_ = df_test.drop(["PassengerId"],axis=1)

X_train = train.values
y_train = train_.values

X_test = test_.values
X_test = X_test.astype(np.float64, copy=False)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# <a id="Model"></a> <br>
# # **6. Modelling : **

# %% [markdown]
# <h3>Titanic survivors prediction: <br>
# a binary classification example</h3>
# Two-class classification, or binary classification, may be the most widely applied kind of machine-learning problem.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#!pip install graphviz

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras
from keras.optimizers import SGD
import graphviz

# %% [markdown]
# <h1>building of a neural network: </h1>
#
# phases of neural :
# - Layers, which are combined into a network (or model)
# - The input data and corresponding targets
# - The loss function, which defines the feedback signal used for learning
# - The optimizer, which determines how learning proceeds

# %% [markdown]
# ## model 1

# %%
# Creating the model
model = Sequential()

# Inputing the first layer with input dimensions
model.add(Dense(18,
                activation='relu',
                input_dim=20,
                kernel_initializer='uniform'))
#The argument being passed to each Dense layer (18) is the number of hidden units of the layer.
# A hidden unit is a dimension in the representation space of the layer.

#Stacks of Dense layers with relu activations can solve a wide range of problems
#(including sentiment classification), and you’ll likely use them frequently.

# Adding an Dropout layer to previne from overfitting
model.add(Dropout(0.50))

#adding second hidden layer
model.add(Dense(60,
                kernel_initializer='uniform',
                activation='relu'))

# Adding another Dropout layer
model.add(Dropout(0.50))

# adding the output layer that is binary [0,1]
model.add(Dense(1,
                kernel_initializer='uniform',
                activation='sigmoid'))
#With such a scalar sigmoid output on a binary classification problem, the loss
#function you should use is binary_crossentropy

#Visualizing the model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 18)                  │             378 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 18)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 60)                  │           1,140 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 60)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              61 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,579 (6.17 KB)
#  Trainable params: 1,579 (6.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# using layers with relu activations can solve a wide range of problems (including sentiment classification), and you’ll likely use them frequently.

# %% [markdown]
# Finally, we need to choose a loss function and an optimizer.

# %%
#Creating an Stochastic Gradient Descent
sgd = SGD(learning_rate = 0.01, momentum = 0.9) # Changed lr to learning_rate

# Compiling our model
model.compile(optimizer = sgd,
                   loss = 'binary_crossentropy',
                   metrics = ['accuracy'])
#optimizers list
#optimizers['SGD', 'RMSprop', 'Adagrad', 'Adadelta', 'Adam', 'Adamax', 'Nadam']

# Fitting the ANN to the Training set
model.fit(X_train, y_train,
               batch_size = 60,
               epochs = 30, verbose=2)
# Out:
# Epoch 1/30
# 15/15 - 3s - 228ms/step - accuracy: 0.6027 - loss: 0.6900
# Epoch 2/30
# 15/15 - 0s - 12ms/step - accuracy: 0.6162 - loss: 0.6795
# Epoch 3/30
# 15/15 - 0s - 8ms/step - accuracy: 0.6162 - loss: 0.6713
# Epoch 4/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6678
# Epoch 5/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6663
# Epoch 6/30
# 15/15 - 0s - 3ms/step - accuracy: 0.6162 - loss: 0.6657
# Epoch 7/30
# 15/15 - 0s - 3ms/step - accuracy: 0.6162 - loss: 0.6652
# Epoch 8/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6650
# Epoch 9/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6647
# Epoch 10/30
# 15/15 - 0s - 3ms/step - accuracy: 0.6162 - loss: 0.6640
# Epoch 11/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6635
# Epoch 12/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6629
# Epoch 13/30
# 15/15 - 0s - 5ms/step - accuracy: 0.6162 - loss: 0.6621
# Epoch 14/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6162 - loss: 0.6609
# Epoch 15/30
# 15/15 - 0s - 5ms/step - accuracy: 0.6162 - loss: 0.6594
# Epoch 16/30
# 15/15 - 0s - 9ms/step - accuracy: 0.6162 - loss: 0.6561
# Epoch 17/30
# 15/15 - 0s - 9ms/step - accuracy: 0.6162 - loss: 0.6529
# Epoch 18/30
# 15/15 - 0s - 10ms/step - accuracy: 0.6162 - loss: 0.6459
# Epoch 19/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6251 - loss: 0.6372
# Epoch 20/30
# 15/15 - 0s - 9ms/step - accuracy: 0.6431 - loss: 0.6237
# Epoch 21/30
# 15/15 - 0s - 4ms/step - accuracy: 0.6880 - loss: 0.6034
# Epoch 22/30
# 15/15 - 0s - 8ms/step - accuracy: 0.7407 - loss: 0.5727
# Epoch 23/30
# 15/15 - 0s - 4ms/step - accuracy: 0.7643 - loss: 0.5421
# Epoch 24/30
# 15/15 - 0s - 4ms/step - accuracy: 0.7632 - loss: 0.5324
# Epoch 25/30
# 15/15 - 0s - 4ms/step - accuracy: 0.7935 - loss: 0.5026
# Epoch 26/30
# 15/15 - 0s - 3ms/step - accuracy: 0.7800 - loss: 0.4916
# Epoch 27/30
# 15/15 - 0s - 4ms/step - accuracy: 0.7811 - loss: 0.4785
# Epoch 28/30
# 15/15 - 0s - 4ms/step - accuracy: 0.7980 - loss: 0.4784
# Epoch 29/30
# 15/15 - 0s - 3ms/step - accuracy: 0.7924 - loss: 0.4750
# Epoch 30/30
# 15/15 - 0s - 4ms/step - accuracy: 0.8103 - loss: 0.4656

# %% [markdown]
# Because you’re facing a binary classification problem and the output of your network is a probability (you end your network with a single-unit layer with a sigmoid activation), it’s best to use the <i>binary_crossentropy</i> loss.

# %% [markdown]
# ## Predicting X_test

# %%
y_preds = model.predict(X_test)

submission = pd.read_csv("gender_submission.csv", index_col='PassengerId')
submission['Survived'] = y_preds.astype(int)
submission.to_csv('TitanicKNN.csv')
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# <h1>Evaluating the model</h1>

# %%
scores = model.evaluate(X_train, y_train, batch_size=30)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8128 - loss: 0.4351
# compile_metrics: 81.71%

# %% [markdown]
# Not bad result to a simple model! Let's now verify the validation of our model, to see and understand the learning curve

# %% [markdown]
# <a id="Validation"></a> <br>
# # **7. Validation: **

# %%
# Fit the model
history = model.fit(X_train, y_train, validation_split=0.20,
                    epochs=180, batch_size=10, verbose=0)

# %% [markdown]
# Let's look this keys values further

# %%
# summarizing historical accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
#  this is a overffiting

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## modele 2

# %%
from keras.regularizers import l2

# ... (Rest of your code) ...

# Creating the model with L2 regularization
model_l2 = Sequential()

# Input layer with L2 regularization
model_l2.add(Dense(18, activation='relu', input_dim=20, kernel_initializer='uniform', kernel_regularizer=l2(0.01)))
model_l2.add(Dropout(0.5))

# Second hidden layer with L2 regularization
model_l2.add(Dense(60, kernel_initializer='uniform', activation='relu', kernel_regularizer=l2(0.01)))
model_l2.add(Dropout(0.5))

# Output layer
model_l2.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))

# Recreate the optimizer for the new model
sgd = SGD(learning_rate=0.01, momentum=0.9) # Create a new SGD instance

# Compile the model with the new optimizer
model_l2.compile(optimizer=sgd, loss='binary_crossentropy', metrics=['accuracy'])

# Fit the model
history_l2 = model_l2.fit(X_train, y_train, validation_split=0.20, epochs=180, batch_size=10, verbose=0)

# %%
# Plotting accuracy
plt.plot(history_l2.history['accuracy'])
plt.plot(history_l2.history['val_accuracy'])
plt.title('Model 1: L2 Regularization - Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Plotting loss
plt.plot(history_l2.history['loss'])
plt.plot(history_l2.history['val_loss'])
plt.title('Model 1: L2 Regularization - Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# mode 2

# %% [markdown]
# # model 3

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Assuming X_train and y_train are your original training data
X_train_train, X_train_test, y_train_train, y_train_test = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)  # Split data

# Initialize the ANN
ann = Sequential()

# Input layer and first hidden layer with L2 regularization and dropout
ann.add(Dense(units=14, activation='relu', input_dim=X_train_train.shape[1], kernel_regularizer=l2(0.01)))
ann.add(Dropout(0.3))

# Second hidden layer with L2 regularization and dropout
ann.add(Dense(units=14, activation='relu', kernel_regularizer=l2(0.01)))
ann.add(Dropout(0.3))

# Output layer
ann.add(Dense(units=1, activation='sigmoid'))

# Compile the model
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Fit the model with early stopping and store the history
history = ann.fit(X_train_train, y_train_train, batch_size=8, epochs=100,
                    validation_data=(X_train_test, y_train_test),
                    callbacks=[early_stopping])

# Evaluate the model on the training set
train_accuracy = ann.evaluate(X_train_train, y_train_train, verbose=0)[1]
print(f"Train Accuracy: {train_accuracy}")

# Evaluate the model on the test set
test_accuracy = ann.evaluate(X_train_test, y_train_test, verbose=0)[1]
print(f"Test Accuracy: {test_accuracy}")

# Plot training and validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training and validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4064 - loss: 1.2031 - val_accuracy: 0.6369 - val_loss: 0.8944
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6613 - loss: 0.9201 - val_accuracy: 0.7542 - val_loss: 0.7964
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6733 - loss: 0.8530 - val_accuracy: 0.7933 - val_loss: 0.7378
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7391 - loss: 0.7502 - val_accuracy: 0.7933 - val_loss: 0.6915
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.7148 - val_accuracy: 0.7821 - val_loss: 0.6621
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7667 - loss: 0.6701 - val_accuracy: 0.7821 - val_loss: 0.6367
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7651 - loss: 0.6822 - val_accuracy: 0.7933 - val_loss: 0.6173
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7958 - loss: 0.5988 - val_accuracy: 0.7877 - val_loss: 0.5948
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7775 - loss: 0.6198 - val_accuracy: 0.7933 - val_loss: 0.5840
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8140 - loss: 0.5649 - val_accuracy: 0.7933 - val_loss: 0.5702
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7603 - loss: 0.6155 - val_accuracy: 0.7933 - val_loss: 0.5558
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8075 - loss: 0.5600 - val_accuracy: 0.7933 - val_loss: 0.5468
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8011 - loss: 0.5571 - val_accuracy: 0.7933 - val_loss: 0.5377
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8117 - loss: 0.5429 - val_accuracy: 0.7933 - val_loss: 0.5294
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7665 - loss: 0.5598 - val_accuracy: 0.7877 - val_loss: 0.5225
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8113 - loss: 0.5250 - val_accuracy: 0.7877 - val_loss: 0.5182
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8083 - loss: 0.5219 - val_accuracy: 0.7821 - val_loss: 0.5118
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8206 - loss: 0.5135 - val_accuracy: 0.7933 - val_loss: 0.5102
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7935 - loss: 0.5459 - val_accuracy: 0.7933 - val_loss: 0.5063
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7892 - loss: 0.5189 - val_accuracy: 0.7989 - val_loss: 0.5032
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8226 - loss: 0.5024 - val_accuracy: 0.8045 - val_loss: 0.5023
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7973 - loss: 0.5327 - val_accuracy: 0.7933 - val_loss: 0.5031
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8277 - loss: 0.4799 - val_accuracy: 0.7989 - val_loss: 0.5018
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8127 - loss: 0.4785 - val_accuracy: 0.7989 - val_loss: 0.4990
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7897 - loss: 0.5292 - val_accuracy: 0.7989 - val_loss: 0.4986
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8178 - loss: 0.4751 - val_accuracy: 0.7989 - val_loss: 0.4933
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8075 - loss: 0.4756 - val_accuracy: 0.7989 - val_loss: 0.4886
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8260 - loss: 0.4725 - val_accuracy: 0.8045 - val_loss: 0.4860
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8207 - loss: 0.4551 - val_accuracy: 0.8045 - val_loss: 0.4825
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8252 - loss: 0.4850 - val_accuracy: 0.8045 - val_loss: 0.4779
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8155 - loss: 0.5044 - val_accuracy: 0.7989 - val_loss: 0.4762
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8347 - loss: 0.4537 - val_accuracy: 0.8045 - val_loss: 0.4751
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.4726 - val_accuracy: 0.8101 - val_loss: 0.4744
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8175 - loss: 0.4909 - val_accuracy: 0.8156 - val_loss: 0.4800
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8382 - loss: 0.4460 - val_accuracy: 0.8156 - val_loss: 0.4765
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8153 - loss: 0.4689 - val_accuracy: 0.8212 - val_loss: 0.4808
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8338 - loss: 0.4636 - val_accuracy: 0.8101 - val_loss: 0.4803
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8470 - loss: 0.4506 - val_accuracy: 0.8156 - val_loss: 0.4803
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8435 - loss: 0.4514 - val_accuracy: 0.8156 - val_loss: 0.4750
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8458 - loss: 0.4412 - val_accuracy: 0.8156 - val_loss: 0.4743
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8167 - loss: 0.5144 - val_accuracy: 0.8045 - val_loss: 0.4740
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8231 - loss: 0.4718 - val_accuracy: 0.8212 - val_loss: 0.4671
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8427 - loss: 0.4435 - val_accuracy: 0.8156 - val_loss: 0.4683
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8381 - loss: 0.4484 - val_accuracy: 0.8268 - val_loss: 0.4708
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8080 - loss: 0.5134 - val_accuracy: 0.8156 - val_loss: 0.4663
# Epoch 46/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8526 - loss: 0.4252 - val_accuracy: 0.8156 - val_loss: 0.4675
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8513 - loss: 0.4350 - val_accuracy: 0.8212 - val_loss: 0.4710
# Epoch 48/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8335 - loss: 0.4908 - val_accuracy: 0.8156 - val_loss: 0.4666
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8448 - loss: 0.4342 - val_accuracy: 0.8156 - val_loss: 0.4644
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8367 - loss: 0.4390 - val_accuracy: 0.8212 - val_loss: 0.4740
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8399 - loss: 0.4460 - val_accuracy: 0.8156 - val_loss: 0.4697
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8316 - loss: 0.4518 - val_accuracy: 0.8101 - val_loss: 0.4694
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8302 - loss: 0.4658 - val_accuracy: 0.8156 - val_loss: 0.4693
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8116 - loss: 0.4649 - val_accuracy: 0.8212 - val_loss: 0.4683
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8284 - loss: 0.4546 - val_accuracy: 0.8212 - val_loss: 0.4704
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8345 - loss: 0.4339 - val_accuracy: 0.8212 - val_loss: 0.4690
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8449 - loss: 0.4378 - val_accuracy: 0.8212 - val_loss: 0.4674
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8243 - loss: 0.4478 - val_accuracy: 0.8212 - val_loss: 0.4624
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8524 - loss: 0.4331 - val_accuracy: 0.8212 - val_loss: 0.4655
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8173 - loss: 0.4523 - val_accuracy: 0.8212 - val_loss: 0.4671
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8399 - loss: 0.4199 - val_accuracy: 0.8212 - val_loss: 0.4701
# Epoch 62/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8453 - loss: 0.4571 - val_accuracy: 0.8212 - val_loss: 0.4715
# Epoch 63/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8511 - loss: 0.4240 - val_accuracy: 0.8212 - val_loss: 0.4640
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8424 - loss: 0.4407 - val_accuracy: 0.8212 - val_loss: 0.4660
# Epoch 65/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8438 - loss: 0.4529 - val_accuracy: 0.8268 - val_loss: 0.4649
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8516 - loss: 0.4496 - val_accuracy: 0.8156 - val_loss: 0.4653
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8324 - loss: 0.4651 - val_accuracy: 0.8156 - val_loss: 0.4646
# Epoch 68/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8424 - loss: 0.4455 - val_accuracy: 0.8156 - val_loss: 0.4604
# Epoch 69/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8635 - loss: 0.4024 - val_accuracy: 0.8156 - val_loss: 0.4642
# Epoch 70/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8349 - loss: 0.4809 - val_accuracy: 0.8156 - val_loss: 0.4592
# Epoch 71/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8306 - loss: 0.4561 - val_accuracy: 0.8212 - val_loss: 0.4649
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8573 - loss: 0.4246 - val_accuracy: 0.8212 - val_loss: 0.4612
# Epoch 73/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8538 - loss: 0.4174 - val_accuracy: 0.8212 - val_loss: 0.4614
# Epoch 74/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8669 - loss: 0.3997 - val_accuracy: 0.8156 - val_loss: 0.4605
# Epoch 75/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8510 - loss: 0.4054 - val_accuracy: 0.8212 - val_loss: 0.4684
# Epoch 76/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8363 - loss: 0.4598 - val_accuracy: 0.8156 - val_loss: 0.4634
# Epoch 77/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8238 - loss: 0.4477 - val_accuracy: 0.8324 - val_loss: 0.4605
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8581 - loss: 0.4095 - val_accuracy: 0.8212 - val_loss: 0.4650
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8608 - loss: 0.3923 - val_accuracy: 0.8212 - val_loss: 0.4683
# Epoch 80/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8409 - loss: 0.4330 - val_accuracy: 0.8268 - val_loss: 0.4660
# Train Accuracy: 0.8553370833396912
# Test Accuracy: 0.8156424760818481
